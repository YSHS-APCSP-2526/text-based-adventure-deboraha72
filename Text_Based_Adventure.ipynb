# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-deboraha72/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def haunted_house():
  print("WELCOME to the haunted house. \n\nDarkness falls upon this house. \nEnter now, if you are able. \nAll are welcome, with one exception.\nThe price of admission is more than a trifle.\nHaunting awaits those who cross the threshold. ")
  answer=input("State your choice to enter or not: Yes/No   ").lower()

  if answer == "yes":
    print ("\nThe door creeks open...\nIn the distance you see a lady...\n her dark hair covers her face, her head drops and rolls over to you.")

  else:
    print("\nYou died!!!")

haunted_house()


import random
my_list = ['C', 'U', 'R', 'S', 'E', 'D']
random.shuffle(my_list)
print(my_list)

print("These are shuffled clues...unshuffle them to move onward")
guess = input("\nWhat is the secret?  ")
if guess == "CURSED":
  print("\nThe lady has disappeared,the lights are now off, you see a bloodstained door.\nYou enter it, finding yourself in a maze.\nWHAT PATH DO YOU CHOOS3?...\nPath 1, Path 2, or Path 3?")
else:
  print("WRONG ANSWER, the price of ignorance is your LIFE.")
guess = input("\nTry again.")
if guess == "CURSED":
  print("\nThe lady has disappeared,the lights are now off, you see a bloodstained door.\nYou enter it, finding yourself in a maze.\nWHAT PATH DO YOU CHOOS3?...\nPath 1, Path 2, or Path 3?")


x = 0
while x < 1:
  guess = input("\nwhich is the correct path? (type number)  ")
  if guess == "1":
    print("\nYou successfully failed")
  if guess == "2":
    print("\nThe jury find you guilty of a fatal error")
  if guess == "3":
    x = 1
    print("\ncorrect path, you follow the 3rd path, and find a butterfly spirit\n You collect it and move foward.\n in the distance you see a shadow figure\nYou use the butterfly spirit to cast it away\nbehind it was a white door\n Do you want to enter? Yes/No")
    answer = input("\nState your choice.. ").lower()
# Out:
# WELCOME to the haunted house.
#
# Darkness falls upon this house.
# Enter now, if you are able.
# All are welcome, with one exception.
# The price of admission is more than a trifle.
# Haunting awaits those who cross the threshold.
# State your choice to enter or not: Yes/No   yes
#
# The door creeks open...
# In the distance you see a lady...
#  her dark hair covers her face, her head drops and rolls over to you.
# ['R', 'D', 'E', 'S', 'C', 'U']
# These are shuffled clues...unshuffle them to move onward
#
# What is the secret?  hgj
# WRONG ANSWER, the price of ignorance is your LIFE.
#
# Try again.CURSED
#
# The lady has disappeared,the lights are now off, you see a bloodstained door.
# You enter it, finding yourself in a maze.
# WHAT PATH DO YOU CHOOS3?...
# Path 1, Path 2, or Path 3?
#
# which is the correct path? (type number)  2
#
# The jury find you guilty of a fatal error
#
# which is the correct path? (type number)  3
#
# ...
